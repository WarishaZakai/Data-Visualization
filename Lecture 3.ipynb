# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_1660\3518078781.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black');

# %%
rng = np.random.default_rng(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.random(2), rng.random(2), marker, color='black',
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1, fontsize=13)
plt.xlim(0, 1.8);

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, '-ok');

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %%
plt.scatter(x, y, marker='o');

# %%
rng = np.random.default_rng(0)
x = rng.normal(size=100)
y = rng.normal(size=100)
colors = rng.random(100)
sizes = 1000 * rng.random(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3)
plt.colorbar();

# %%
from IPython.display import Image
Image(filename='iris dataset.png')

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[0], features[1], alpha=0.4, 
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[0], features[1], alpha=0.4, 
            s=100*features[2], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[1], features[2], alpha=0.4, 
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[1], features[0], alpha=0.4, 
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[2], features[3], alpha=0.4, 
            s=100*features[1], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[2], features[3], alpha=0.4, 
            s=20*features[0], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[2])
plt.ylabel(iris.feature_names[3]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[3], features[2], alpha=0.4, 
            s=20*features[1], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[3])
plt.ylabel(iris.feature_names[2]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[3], features[2], alpha=0.4, 
            s=100*features[0], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[3], features[0], alpha=0.4, 
            s=100*features[1], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[3], features[1], alpha=0.4, 
            s=100*features[0], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[0], features[2], alpha=0.4, 
            s=100*features[1], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[0], features[3], alpha=0.4, 
            s=100*features[1], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[1], features[3], alpha=0.4, 
            s=100*features[2], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[1], features[3], alpha=0.4, 
            s=100*features[0], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[2], features[1], alpha=0.4, 
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[2], features[0], alpha=0.4, 
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[2], features[1], alpha=0.4, 
            s=100*features[0], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[0], features[2], alpha=0.4, 
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[0], features[3], alpha=0.4, 
            s=100*features[2], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[2], features[0], alpha=0.4, 
            s=100*features[1], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[3], features[0], alpha=0.4, 
            s=40*features[2], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[3])
plt.ylabel(iris.feature_names[0]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[3], features[1], alpha=0.4, 
            s=100*features[2], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[1], features[0], alpha=0.4, 
            s=100*features[2], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
from sklearn.datasets import load_iris
iris = load_iris()  #load dataset
features = iris.data.T #transpose to seperate features

plt.scatter(features[1], features[2], alpha=0.4, 
            s=100*features[0], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);
